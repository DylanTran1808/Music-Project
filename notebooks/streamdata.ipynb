# %%
from datasets import load_dataset
import pandas as pd
from huggingface_hub import HfFileSystem

fs = HfFileSystem()
repo = "datasets/CongtyTuban/tessst"

df_2025 = pd.read_json(f"hf://{repo}/Streaming_History_Audio_2025.json")

files = fs.glob(f"{repo}/Streaming_History_Audio_*.json")
df_audio = pd.concat([pd.read_json(f"hf://{f}") for f in files], ignore_index=True)

print(df_audio.head())
# Out:
#                      ts            platform  ms_played conn_country  \
# 0  2018-04-23T16:15:25Z  iOS 11.3 (iPad4,8)      16532           VN
# 1  2018-04-23T16:15:25Z  iOS 11.3 (iPad4,8)       1509           VN
# 2  2018-04-23T16:16:07Z  iOS 11.3 (iPad4,8)       1578           VN
# 3  2018-04-23T16:16:17Z  iOS 11.3 (iPad4,8)       7848           VN
# 4  2018-04-23T16:17:53Z  iOS 11.3 (iPad4,8)       3297           VN
#
#          ip_addr    master_metadata_track_name  \
# 0  171.227.36.30                       FRIENDS
# 1  171.227.36.30                          等你下課
# 2  171.227.36.30                 Nice For What
# 3  171.227.36.30          no tears left to cry
# 4  171.227.36.30  Psycho (feat. Ty Dolla $ign)
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                        Marshmello                          FRIENDS
# 1                          Jay Chou                             等你下課
# 2                             Drake                    Nice For What
# 3                     Ariana Grande             no tears left to cry
# 4                       Post Malone     Psycho (feat. Ty Dolla $ign)
#
#                       spotify_track_uri episode_name  ... audiobook_uri  \
# 0  spotify:track:08bNPGLD8AhKpnnERrAc6G          NaN  ...           NaN
# 1  spotify:track:76WthWB0v0KXUHZoAclMVV          NaN  ...           NaN
# 2  spotify:track:1cTZMwcBJT0Ka3UJPXOeeN          NaN  ...           NaN
# 3  spotify:track:5SxkdsY1ufZzoq9iXceLw9          NaN  ...           NaN
# 4  spotify:track:7wrDRQgHlvDnimrRHfQZxt          NaN  ...           NaN
#
#   audiobook_chapter_uri  audiobook_chapter_title  reason_start  reason_end  \
# 0                   NaN                      NaN      clickrow     endplay
# 1                   NaN                      NaN      clickrow      logout
# 2                   NaN                      NaN      clickrow     endplay
# 3                   NaN                      NaN      clickrow     endplay
# 4                   NaN                      NaN      clickrow     endplay
#
#    shuffle skipped offline  offline_timestamp  incognito_mode
# 0    False   False   False                NaN             0.0
# 1    False   False   False                NaN             0.0
# 2    False   False   False                NaN             0.0
# 3    False   False   False                NaN             0.0
# 4    False   False   False                NaN             0.0
#
# [5 rows x 23 columns]
