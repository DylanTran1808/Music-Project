# %%
import plistlib
from huggingface_hub import HfFileSystem
import pandas as pd

fs = HfFileSystem()
repo = "datasets/CongtyTuban/Streaming-data"


df_2025 = pd.read_json(f"hf://{repo}/raw_spot/Spotify_bhuy/Streaming_History_Video_2024.json")
df_2025
# Out:
#                       ts platform  ms_played conn_country  \
# 0   2024-12-16T13:44:49Z      ios     276160           VN
# 1   2024-12-16T13:44:52Z      ios          0           VN
# 2   2024-12-16T13:44:53Z      ios          0           VN
# 3   2024-12-16T13:44:54Z      ios          0           VN
# 4   2024-12-16T13:44:54Z      ios          0           VN
# 5   2024-12-16T13:44:55Z      ios          0           VN
# 6   2024-12-16T13:49:08Z      ios     252322           VN
# 7   2024-12-16T13:53:04Z      ios     234622           VN
# 8   2024-12-16T13:53:41Z      ios      35770           VN
# 9   2024-12-16T13:53:42Z      ios          0           VN
# 10  2024-12-16T13:53:42Z      ios          0           VN
# 11  2024-12-16T13:53:43Z      ios          0           VN
# 12  2024-12-16T13:53:44Z      ios          0           VN
# 13  2024-12-16T13:53:45Z      ios        130           VN
# 14  2024-12-16T13:53:45Z      ios          0           VN
# 15  2024-12-16T13:57:28Z      ios     222281           VN
# 16  2024-12-16T14:01:03Z      ios     213570           VN
# 17  2024-12-16T14:01:04Z      ios          0           VN
# 18  2024-12-16T14:01:05Z      ios          0           VN
# 19  2024-12-16T14:01:06Z      ios        270           VN
# 20  2024-12-16T14:01:07Z      ios          0           VN
# 21  2024-12-16T14:01:08Z      ios          0           VN
# 22  2024-12-16T14:01:09Z      ios          0           VN
# 23  2024-12-16T14:01:09Z      ios          0           VN
# 24  2024-12-16T14:01:10Z      ios          0           VN
# 25  2024-12-16T14:01:10Z      ios          0           VN
# 26  2024-12-16T14:01:11Z      ios          0           VN
# 27  2024-12-16T14:01:12Z      ios          0           VN
# 28  2024-12-16T14:04:09Z      ios     172860           VN
# 29  2024-12-18T00:18:26Z      ios      57670           VN
# 30  2024-12-23T19:18:55Z  windows       1631           VN
#
#                                    ip_addr      master_metadata_track_name  \
# 0                2a09:bac1:7aa0:10::2e5:10     Hit Me Up (feat. Nomovodka)
# 1                2a09:bac1:7aa0:10::2e5:10  Kẻ Cắp Gặp Bà Già (feat. Binz)
# 2                2a09:bac1:7aa0:10::2e5:10              Thích Em Hơi Nhiều
# 3                2a09:bac1:7aa0:10::2e5:10                   Cứ Chill Thôi
# 4                2a09:bac1:7aa0:10::2e5:10                Die With A Smile
# 5                2a09:bac1:7aa0:10::2e5:10                      Thanh Xuân
# 6                2a09:bac1:7aa0:10::2e5:10                Die With A Smile
# 7              2a09:bac5:d46c:1d0f::2e5:10                      Thanh Xuân
# 8              2a09:bac5:d46c:1d0f::2e5:10                   Ngày Đầu Tiên
# 9              2a09:bac5:d46c:1d0f::2e5:10             Bước Qua Mùa Cô Đơn
# 10             2a09:bac5:d46c:1d0f::2e5:10                       Đi Về Nhà
# 11             2a09:bac5:d46c:1d0f::2e5:10           We Don't Talk Anymore
# 12             2a09:bac5:d46c:1d0f::2e5:10                  Từ Ngày Em Đến
# 13             2a09:bac5:d46c:1d0f::2e5:10           We Don't Talk Anymore
# 14             2a09:bac5:d46c:1d0f::2e5:10             Bước Qua Mùa Cô Đơn
# 15             2a09:bac5:d468:1d0f::2e5:10           We Don't Talk Anymore
# 16             2a09:bac5:d46c:1d0f::2e5:10                  Từ Ngày Em Đến
# 17             2a09:bac5:d46c:1d0f::2e5:10                      Vùng Ký Ức
# 18             2a09:bac5:d46c:1d0f::2e5:10   Ừ Thì Chia Tay (feat. RHYDER)
# 19             2a09:bac5:d46c:1d0f::2e5:10           Ngày Đầu Sau Chia Tay
# 20             2a09:bac5:d46c:1d0f::2e5:10                 Cheating on You
# 21             2a09:bac5:d46c:1d0f::2e5:10               Tình Yêu Ngủ Quên
# 22             2a09:bac5:d46c:1d0f::2e5:10                 Bắt Cóc Con Tim
# 23             2a09:bac5:d46c:1d0f::2e5:10                          Cà Phê
# 24             2a09:bac5:d46c:1d0f::2e5:10                       positions
# 25             2a09:bac5:d46c:1d0f::2e5:10                         Call Me
# 26             2a09:bac5:d46c:1d0f::2e5:10                 MOT NGUOI VI EM
# 27             2a09:bac5:d46c:1d0f::2e5:10    Vườn Hoa Con Cá (feat. Ngắn)
# 28             2a09:bac5:d46b:1d0f::2e5:10                 MOT NGUOI VI EM
# 29               2a09:bac1:7a80:10::23:47e                             NaN
# 30  2001:ee0:50c7:fab0:a8a4:a3a0:dadd:422e                  Water Fountain
#
#    master_metadata_album_artist_name  \
# 0                               Binz
# 1                    Hoàng Thùy Linh
# 2                         Wren Evans
# 3                           Chillies
# 4                          Lady Gaga
# 5                             Da LAB
# 6                          Lady Gaga
# 7                             Da LAB
# 8                           Đức Phúc
# 9                                Vũ.
# 10                               Đen
# 11                      Charlie Puth
# 12                            Da LAB
# 13                      Charlie Puth
# 14                               Vũ.
# 15                      Charlie Puth
# 16                            Da LAB
# 17                          Chillies
# 18                           Captain
# 19                          Đức Phúc
# 20                      Charlie Puth
# 21                         Hoàng Tôn
# 22                         Lou Hoàng
# 23                               MIN
# 24                     Ariana Grande
# 25                        Wren Evans
# 26                              WEAN
# 27                              Olew
# 28                              WEAN
# 29                               NaN
# 30                     Alec Benjamin
#
#               master_metadata_album_album_name  \
# 0                  Hit Me Up (feat. Nomovodka)
# 1               Kẻ Cắp Gặp Bà Già (feat. Binz)
# 2                           Thích Em Hơi Nhiều
# 3                                Cứ Chill Thôi
# 4                             Die With A Smile
# 5                                   Thanh Xuân
# 6                             Die With A Smile
# 7                                   Thanh Xuân
# 8                                Ngày Đầu Tiên
# 9                          Bước Qua Mùa Cô Đơn
# 10                                   Đi Về Nhà
# 11  We Don't Talk Anymore (feat. Selena Gomez)
# 12                              Từ Ngày Em Đến
# 13  We Don't Talk Anymore (feat. Selena Gomez)
# 14                         Bước Qua Mùa Cô Đơn
# 15  We Don't Talk Anymore (feat. Selena Gomez)
# 16                              Từ Ngày Em Đến
# 17                                  Vùng Ký Ức
# 18               Ừ Thì Chia Tay (feat. RHYDER)
# 19                       Ngày Đầu Sau Chia Tay
# 20                             Cheating on You
# 21                           Tình Yêu Ngủ Quên
# 22                             Bắt Cóc Con Tim
# 23                                      Cà Phê
# 24                                   positions
# 25                                     Call Me
# 26                             MOT NGUOI VI EM
# 27                Vườn Hoa Con Cá (feat. Ngắn)
# 28                             MOT NGUOI VI EM
# 29                                         NaN
# 30                              Water Fountain
#
#                        spotify_track_uri    episode_name  ... audiobook_uri  \
# 0   spotify:track:46E9MtcAl7iYATRTWKRtyk             NaN  ...           NaN
# 1   spotify:track:3Yk66PsAWlvp7cx3xIQiXk             NaN  ...           NaN
# 2   spotify:track:3MZfomyfL0GoZfXPTATN3Z             NaN  ...           NaN
# 3   spotify:track:1PeWLO4PcOkiGV2D0ISvn4             NaN  ...           NaN
# 4   spotify:track:1Ywk7HecwsfJWy2pxaaQZM             NaN  ...           NaN
# 5   spotify:track:4YmTOCGn591pJOkgqT5b8X             NaN  ...           NaN
# 6   spotify:track:1Ywk7HecwsfJWy2pxaaQZM             NaN  ...           NaN
# 7   spotify:track:4YmTOCGn591pJOkgqT5b8X             NaN  ...           NaN
# 8   spotify:track:5MkKWW8BdUMY5SjFDXOpL4             NaN  ...           NaN
# 9   spotify:track:2HaLnc6PBikk99rX4iViad             NaN  ...           NaN
# 10  spotify:track:4Z1wArMXGVG43GjrWgn9C5             NaN  ...           NaN
# 11  spotify:track:7l5uG9bFggKPJyU6rNAhsr             NaN  ...           NaN
# 12  spotify:track:48Xytp1ZVayvOJirJcKHGT             NaN  ...           NaN
# 13  spotify:track:7l5uG9bFggKPJyU6rNAhsr             NaN  ...           NaN
# 14  spotify:track:2HaLnc6PBikk99rX4iViad             NaN  ...           NaN
# 15  spotify:track:7l5uG9bFggKPJyU6rNAhsr             NaN  ...           NaN
# 16  spotify:track:48Xytp1ZVayvOJirJcKHGT             NaN  ...           NaN
# 17  spotify:track:1AanAd36QNz2Mog3Cqa6yH             NaN  ...           NaN
# 18  spotify:track:4BhvYdRPj8yw97OGWKYPtb             NaN  ...           NaN
# 19  spotify:track:2J5tFcxllg7kddQB71Aars             NaN  ...           NaN
# 20  spotify:track:5EOdxOCZGlDZZrjHnLeGas             NaN  ...           NaN
# 21  spotify:track:2pHzC6NlijjRBwWCsSBCHe             NaN  ...           NaN
# 22  spotify:track:6R4PK6EEQdWmHdKM67YdJE             NaN  ...           NaN
# 23  spotify:track:2pC0NnWhPTAnEImDfWgtTr             NaN  ...           NaN
# 24  spotify:track:403oLfci9HNYbMrU0cTrGe             NaN  ...           NaN
# 25  spotify:track:5Z3EqFo2YBeC2AXysxrtMC             NaN  ...           NaN
# 26  spotify:track:60HdvyDsPSqGsLCQjo0GUk             NaN  ...           NaN
# 27  spotify:track:7102ZYbFZaEV0RjU7edXL2             NaN  ...           NaN
# 28  spotify:track:60HdvyDsPSqGsLCQjo0GUk             NaN  ...           NaN
# 29                                   NaN  Tíc Tắc - Bray  ...           NaN
# 30  spotify:track:1q0TlIdCiaEvQMsNdiEGDa             NaN  ...           NaN
#
#    audiobook_chapter_uri  audiobook_chapter_title  reason_start  reason_end  \
# 0                    NaN                      NaN       playbtn     endplay
# 1                    NaN                      NaN        fwdbtn      fwdbtn
# 2                    NaN                      NaN        fwdbtn      fwdbtn
# 3                    NaN                      NaN        fwdbtn      fwdbtn
# 4                    NaN                      NaN        fwdbtn      fwdbtn
# 5                    NaN                      NaN        fwdbtn     backbtn
# 6                    NaN                      NaN       backbtn   trackdone
# 7                    NaN                      NaN     trackdone   trackdone
# 8                    NaN                      NaN     trackdone      fwdbtn
# 9                    NaN                      NaN        fwdbtn      fwdbtn
# 10                   NaN                      NaN        fwdbtn      fwdbtn
# 11                   NaN                      NaN        fwdbtn      fwdbtn
# 12                   NaN                      NaN        fwdbtn     backbtn
# 13                   NaN                      NaN       backbtn     backbtn
# 14                   NaN                      NaN       backbtn      fwdbtn
# 15                   NaN                      NaN        fwdbtn   trackdone
# 16                   NaN                      NaN     trackdone      fwdbtn
# 17                   NaN                      NaN        fwdbtn      fwdbtn
# 18                   NaN                      NaN        fwdbtn      fwdbtn
# 19                   NaN                      NaN        fwdbtn      fwdbtn
# 20                   NaN                      NaN        fwdbtn      fwdbtn
# 21                   NaN                      NaN        fwdbtn      fwdbtn
# 22                   NaN                      NaN        fwdbtn      fwdbtn
# 23                   NaN                      NaN        fwdbtn      fwdbtn
# 24                   NaN                      NaN        fwdbtn      fwdbtn
# 25                   NaN                      NaN        fwdbtn      fwdbtn
# 26                   NaN                      NaN        fwdbtn      fwdbtn
# 27                   NaN                      NaN        fwdbtn     backbtn
# 28                   NaN                      NaN       backbtn     endplay
# 29                   NaN                      NaN      clickrow     backbtn
# 30                   NaN                      NaN       unknown     unknown
#
#     shuffle skipped offline  offline_timestamp  incognito_mode
# 0     False    True   False         1734356402           False
# 1     False    True   False         1734356692           False
# 2     False    True   False         1734356693           False
# 3     False    True   False         1734356694           False
# 4     False    True   False         1734356694           False
# 5     False    True   False         1734356695           False
# 6     False   False   False         1734356695           False
# 7     False   False   False         1734356949           False
# 8     False    True   False         1734357185           False
# 9     False    True   False         1734357222           False
# 10    False    True   False         1734357222           False
# 11    False    True   False         1734357223           False
# 12    False    True   False         1734357224           False
# 13    False    True   False         1734357224           False
# 14    False    True   False         1734357225           False
# 15    False   False   False         1734357226           False
# 16    False    True   False         1734357449           False
# 17    False    True   False         1734357664           False
# 18    False    True   False         1734357665           False
# 19    False    True   False         1734357666           False
# 20    False    True   False         1734357667           False
# 21    False    True   False         1734357668           False
# 22    False    True   False         1734357669           False
# 23    False    True   False         1734357669           False
# 24    False    True   False         1734357670           False
# 25    False    True   False         1734357669           False
# 26    False    True   False         1734357671           False
# 27    False    True   False         1734357672           False
# 28    False    True   False         1734357673           False
# 29    False    True   False         1734481048           False
# 30    False   False   False         1734981528           False
#
# [31 rows x 23 columns]

# %%
df_2025.columns.tolist()
# Out:
# ['ts',
#  'platform',
#  'ms_played',
#  'conn_country',
#  'ip_addr',
#  'master_metadata_track_name',
#  'master_metadata_album_artist_name',
#  'master_metadata_album_album_name',
#  'spotify_track_uri',
#  'episode_name',
#  'episode_show_name',
#  'spotify_episode_uri',
#  'audiobook_title',
#  'audiobook_uri',
#  'audiobook_chapter_uri',
#  'audiobook_chapter_title',
#  'reason_start',
#  'reason_end',
#  'shuffle',
#  'skipped',
#  'offline',
#  'offline_timestamp',
#  'incognito_mode']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203 entries, 369 to 820
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Track ID               203 non-null    int64
#  1   Name                   203 non-null    object
#  2   Kind                   185 non-null    object
#  3   Size                   203 non-null    int64
#  4   Total Time             203 non-null    int64
#  5   Track Number           200 non-null    float64
#  6   Year                   200 non-null    float64
#  7   Date Modified          203 non-null    datetime64[ns]
#  8   Date Added             114 non-null    datetime64[ns]
#  9   Bit Rate               203 non-null    int64
#  10  Sample Rate            203 non-null    int64
#  11  Normalization          64 non-null     float64
#  12  Persistent ID          203 non-null    object
#  13  Track Type             203 non-null    object
#  14  Location               52 non-null     object
#  15  File Folder Count      52 non-null     float64
#  16  Library Folder Count   52 non-null     float64
#  17  Artist                 201 non-null    object
#  18  Album Artist           179 non-null    object
#  19  Composer               162 non-null    object
#  20  Album                  198 non-null    object
#  21  Genre                  198 non-null    object
#  22  Disc Number            198 non-null    float64
#  23  Disc Count             179 non-null    float64
#  24  Track Count            177 non-null    float64
#  25  Play Count             154 non-null    float64
#  26  Play Date              154 non-null    float64
#  27  Play Date UTC          154 non-null    datetime64[ns]
#  28  Release Date           198 non-null    datetime64[ns]
#  29  Sort Album             180 non-null    object
#  30  Sort Artist            179 non-null    object
#  31  Sort Name              179 non-null    object
#  32  Protected              47 non-null     object
#  33  Apple Music            198 non-null    object
#  34  Artwork Count          151 non-null    float64
#  35  Playlist Only          91 non-null     object
#  36  Skip Count             80 non-null     float64
#  37  Skip Date              82 non-null     datetime64[ns]
#  38  Favorited              95 non-null     object
#  39  Loved                  95 non-null     object
#  40  Compilation            7 non-null      object
#  41  Part Of Gapless Album  7 non-null      object
#  42  Sort Album Artist      4 non-null      object
#  43  Explicit               9 non-null      object
#  44  Sort Composer          1 non-null      object
# dtypes: datetime64[ns](5), float64(12), int64(5), object(23)
# memory usage: 73.0+ KB

# %%
boolean_columns = [
    "Explicit",
    "Apple Music",
    "Favorited",
    "Loved",
    "Protected",
    "Purchased",
    "Compilation",
    "Playlist Only",
    "Part Of Gapless Album",
    "Album Rating Computed",
    "Clean"
]

for column in boolean_columns:
    print("\n", column)
    print(df[column].value_counts(dropna=False))
# Out:
#  Explicit
# Explicit
# NaN     194
# True      9
# Name: count, dtype: int64
#
#  Apple Music
# Apple Music
# True    198
# NaN       5
# Name: count, dtype: int64
#
#  Favorited
# Favorited
# NaN     108
# True     95
# Name: count, dtype: int64
#
#  Loved
# Loved
# NaN     108
# True     95
# Name: count, dtype: int64
#
#  Protected
# Protected
# NaN     156
# True     47
# Name: count, dtype: int64
#
#  Purchased
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/predictAI/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Purchased'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 17
#      15 for column in boolean_columns:
#      16     print("\n", column)
# ---> 17     print(df[column].value_counts(dropna=False))
#
# File ~/miniconda3/envs/predictAI/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/miniconda3/envs/predictAI/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Purchased'

# %%
rename_map = {
    "Track ID": "track_id",
    "Name": "name",
    "Kind": "kind",
    "Size": "size_bytes",
    "Total Time": "total_time_ms",
    "Date Modified": "date_modified",
    "Date Added": "date_added",
    "Bit Rate": "bit_rate",
    "Sample Rate": "sample_rate",
    "Play Count": "play_count",
    "Play Date": "play_date",
    "Play Date UTC": "play_date_utc",
    "Skip Count": "skip_count",
    "Skip Date": "skip_date",
    "Normalization": "normalization",
    "Persistent ID": "persistent_id",
    "Track Type": "track_type",
    "Location": "location",
    "File Folder Count": "file_folder_count",
    "Library Folder Count": "library_folder_count",
    "Artist": "artist",
    "Album Artist": "album_artist",
    "Composer": "composer",
    "Album": "album",
    "Genre": "genre",
    "Disc Number": "disc_number",
    "Disc Count": "disc_count",
    "Track Number": "track_number",
    "Track Count": "track_count",
    "Year": "year",
    "Release Date": "release_date",
    "Artwork Count": "artwork_count",
    "Sort Album": "sort_album",
    "Sort Artist": "sort_artist",
    "Sort Name": "sort_name",
    "Explicit": "explicit",
    "Apple Music": "apple_music",
    "Favorited": "favorited",
    "Loved": "loved",
    "Protected": "protected",
    "Purchased": "purchased",
    "Compilation": "compilation",
    "Playlist Only": "playlist_only",
    "Sort Album Artist": "sort_album_artist",
    "Work": "work",
    "Movement Name": "movement_name",
    "Grouping": "grouping",
    "Movement Number": "movement_number",
    "Movement Count": "movement_count",
    "Part Of Gapless Album": "part_of_gapless_album",
    "Rating": "rating",
    "Album Rating": "album_rating",
    "Album Rating Computed": "album_rating_computed",
    "Sort Composer": "sort_composer",
    "Clean": "clean"
}

df = df.rename(columns=rename_map)

# %%
print(df.columns.tolist())
# Out:
# ['track_id', 'name', 'kind', 'size_bytes', 'total_time_ms', 'track_number', 'year', 'date_modified', 'date_added', 'bit_rate', 'sample_rate', 'normalization', 'persistent_id', 'track_type', 'location', 'file_folder_count', 'library_folder_count', 'artist', 'album_artist', 'composer', 'album', 'genre', 'disc_number', 'disc_count', 'track_count', 'play_count', 'play_date', 'play_date_utc', 'release_date', 'sort_album', 'sort_artist', 'sort_name', 'protected', 'apple_music', 'artwork_count', 'playlist_only', 'skip_count', 'skip_date', 'favorited', 'loved', 'compilation', 'part_of_gapless_album', 'sort_album_artist', 'explicit', 'sort_composer']

# %%
df = df.drop(columns={"play_date"})

# %%
integer_columns = [
    "bit_rate",
    "sample_rate",
    "play_count",
    "skip_count",
    "normalization",
    "file_folder_count",
    "library_folder_count",
    "disc_number",
    "disc_count",
    "track_number",
    "track_count",
    "year",
    "artwork_count",
    "movement_number",
    "movement_count",
    "rating",
    "album_rating"
]

for column in integer_columns:
    df[column] = df[column].astype("Int64")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/predictAI/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'movement_number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 22
#       1 integer_columns = [
#       2     "bit_rate",
#       3     "sample_rate",
#    (...)     18     "album_rating"
#      19 ]
#      21 for column in integer_columns:
# ---> 22     df[column] = df[column].astype("Int64")
#
# File ~/miniconda3/envs/predictAI/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/miniconda3/envs/predictAI/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'movement_number'

# %%
boolean_columns = [
    "explicit",
    "apple_music",
    "favorited",
    "loved",
    "protected",
    "purchased",
    "compilation",
    "playlist_only",
    "part_of_gapless_album",
    "album_rating_computed",
    "clean"
]

for column in boolean_columns:
    df[column] = df[column].astype("boolean")
