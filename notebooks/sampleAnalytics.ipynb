# %%
import music_project.connectors.HuggingFaceConnector as hfc
import importlib
importlib.reload(hfc)
# Out:
# <module 'music_project.connectors.HuggingFaceConnector' from '/Users/dylan/Documents/Project Music/Music-Project/src/music_project/connectors/HuggingFaceConnector.py'>

# %%
df = hfc.apple_music_library_to_df(username="kien")

# %%
df.columns.tolist()
# Out:
# ['track_id',
#  'name',
#  'kind',
#  'size_bytes',
#  'total_time_ms',
#  'date_modified',
#  'date_added',
#  'bit_rate',
#  'sample_rate',
#  'play_count',
#  'play_date',
#  'play_date_utc',
#  'skip_count',
#  'skip_date',
#  'normalization',
#  'persistent_id',
#  'track_type',
#  'location',
#  'file_folder_count',
#  'library_folder_count',
#  'artist',
#  'album_artist',
#  'composer',
#  'album',
#  'genre',
#  'disc_number',
#  'disc_count',
#  'track_number',
#  'track_count',
#  'year',
#  'release_date',
#  'artwork_count',
#  'sort_album',
#  'sort_artist',
#  'sort_name',
#  'explicit',
#  'apple_music',
#  'favorited',
#  'loved',
#  'protected',
#  'purchased',
#  'compilation',
#  'playlist_only',
#  'sort_album_artist',
#  'work',
#  'movement_name',
#  'grouping',
#  'movement_number',
#  'movement_count',
#  'part_of_gapless_album',
#  'rating',
#  'album_rating',
#  'album_rating_computed',
#  'sort_composer',
#  'clean',
#  'duration_sec',
#  'source_user']

# %%
exclude = ["Bit Rate","Sample Rate","Normalization",""]
# Out:
#   Cell In[15], line 1
#     exclude = ["Bit Rate","Sample Rate","Normalization"<]
#                                                         ^
# SyntaxError: invalid syntax

# %%
spot_df = hfc.spotify_user_to_df(username="bhuy")

# %%
spot_df
# Out:
#                         ts platform  ms_played conn_country  \
# 0     2024-11-21T17:03:34Z      ios       4800           VN
# 1     2024-11-21T17:05:50Z      ios     135743           VN
# 2     2024-11-21T17:06:28Z      ios      38400           VN
# 3     2024-11-21T17:09:49Z      ios     201589           VN
# 4     2024-11-21T17:12:51Z      ios     181558           VN
# ...                    ...      ...        ...          ...
# 7467  2025-10-16T13:27:39Z      ios        140           VN
# 7468  2025-10-25T04:05:11Z      ios          0           VN
# 7469  2026-01-07T17:37:31Z      ios          0           VN
# 7470  2026-02-18T10:04:21Z      ios       2090           VN
# 7471  2026-04-21T01:03:22Z      ios        165           VN
#
#                                     ip_addr        master_metadata_track_name  \
# 0               2a09:bac5:d46e:16c8::245:46  Let's Fall in Love for the Night
# 1               2a09:bac5:d46e:16c8::245:46                          Tương Tư
# ...
